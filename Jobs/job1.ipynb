# %%
from pyspark.sql import SparkSession
from pyspark import SparkConf
import pyspark.sql.functions as F
from google.cloud import storage
import os

serviceAccount = 'C:\\Users\\quel-\\OneDrive\\Área de Trabalho\\CURSOS\\Curso - Python\\Projeto_final\\Jobs\\striking-shadow-349020-c0b04aecfb6a.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

client = storage.Client()
bucket = client.get_bucket('projeto-individual')
bucket.blob('marketing_campaign.csv')
path = 'gs://projeto-individual/marketing_campaign.csv'

spark = ( SparkSession.builder
                        .master("local")
                        .appName("aula-inicial")
                        .config("spark.ui.port", "4050")
                        .config("spark.jars", 'https://storage.googleapis.com/hadoop-lib/gcs/gcs-connector-hadoop2-latest.jar')
                        .getOrCreate() 
        )
dfs_arrecadacao = (spark.read.format("csv")
                  .option("header", "true")
                  .option("inferschema", "true")
                  .option("delimiter", ";")
                  .option("encoding", "latin1")
                  .load(path)
)
# # Conectando com a SparkSession:
# spark = (SparkSession.builder.master("local")
#          .appName("job-1")
#          .config("spark.ui.port", "4050")
#          .config("spark.jars", 'https://storage.googleapis.com/hadoop-lib/gcs/gcs-connector-hadoop2-latest.jar')
#          .getOrCreate()
#          )
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# c:\Users\quel-\OneDrive\Área de Trabalho\CURSOS\Curso - Python\Projeto_final\Jobs\job1.ipynb Cell 1' in <cell line: 15>()
#      <a href='vscode-notebook-cell:/c%3A/Users/quel-/OneDrive/%C3%81rea%20de%20Trabalho/CURSOS/Curso%20-%20Python/Projeto_final/Jobs/job1.ipynb#ch0000000?line=11'>12</a> bucket.blob('marketing_campaign.csv')
#      <a href='vscode-notebook-cell:/c%3A/Users/quel-/OneDrive/%C3%81rea%20de%20Trabalho/CURSOS/Curso%20-%20Python/Projeto_final/Jobs/job1.ipynb#ch0000000?line=12'>13</a> path = 'gs://projeto-individual/marketing_campaign.csv'
# ---> <a href='vscode-notebook-cell:/c%3A/Users/quel-/OneDrive/%C3%81rea%20de%20Trabalho/CURSOS/Curso%20-%20Python/Projeto_final/Jobs/job1.ipynb#ch0000000?line=14'>15</a> spark = ( SparkSession.builder
# ...

# %%
dfs_arrecadacao = (spark.read.format("csv")
                  .option("header", "true")
                  .option("inferschema", "true")
                  .option("delimiter", ";")
                  .option("encoding", "latin1")
                  .load("gs://projeto-individual/marketing_campain_tratado.csv")
)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# c:\Users\quel-\OneDrive\Área de Trabalho\CURSOS\Curso - Python\Projeto_final\Jobs\job1.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/quel-/OneDrive/%C3%81rea%20de%20Trabalho/CURSOS/Curso%20-%20Python/Projeto_final/Jobs/job1.ipynb#ch0000005?line=0'>1</a> dfs_arrecadacao = (spark.read.format("csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/quel-/OneDrive/%C3%81rea%20de%20Trabalho/CURSOS/Curso%20-%20Python/Projeto_final/Jobs/job1.ipynb#ch0000005?line=1'>2</a>                   .option("header", "true")
#       <a href='vscode-notebook-cell:/c%3A/Users/quel-/OneDrive/%C3%81rea%20de%20Trabalho/CURSOS/Curso%20-%20Python/Projeto_final/Jobs/job1.ipynb#ch0000005?line=2'>3</a>                   .option("inferschema", "true")
# ...

# %%
dfs_arrecadacao.writeTo("catalog.db.table").append()  
dfs_barragens.writeTo(                              
    "catalog.db.table"
).partitionedBy("col").createOrReplace()
